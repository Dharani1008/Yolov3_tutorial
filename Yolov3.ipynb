# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls '/content/drive/My Drive/yolo_custom_model_Training'
# Out:
# backup	custom_data  custom_data.zip  custom_weight  darknet

# %%
# !git clone 'https://github.com/AlexeyAB/darknet'  '/content/drive/My Drive/yolo_custom_model_Training/darknet'
# Out:
# Cloning into '/content/drive/My Drive/yolo_custom_model_Training/darknet'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 14370 (delta 3), reused 5 (delta 1), pack-reused 14358
# Receiving objects: 100% (14370/14370), 13.10 MiB | 8.13 MiB/s, done.
# Resolving deltas: 100% (9767/9767), done.
# Checking out files: 100% (2021/2021), done.

# %%
# %cd /content/drive/My Drive/yolo_custom_model_Training/darknet
# Out:
# /content/drive/My Drive/yolo_custom_model_Training/darknet

# %%
# !ls
# Out:
# 3rdparty	DarknetConfig.cmake.in	include		       results
# build		darknet_images.py	json_mjpeg_streams.sh  scripts
# build.ps1	darknet.py		LICENSE		       src
# build.sh	darknet_video.py	Makefile	       video_yolov3.sh
# cfg		data			net_cam_v3.sh	       video_yolov4.sh
# cmake		image_yolov3.sh		net_cam_v4.sh
# CMakeLists.txt	image_yolov4.sh		README.md

# %%
# %cd /content/drive/My Drive/yolo_custom_model_Training
# Out:
# /content/drive/My Drive/yolo_custom_model_Training

# %%
# change makefile to have GPU and OPENCV enabled
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !sed -i 's/CUDNN_HALF=0/CUDNN_HALF=1/' Makefile
# Out:
# /content/drive/My Drive/yolo_custom_model_Training/darknet

# %%
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
# ...

# %% [markdown]
# Inside the darknet folder there will be a clg folder. Inside that there will be many config files. Select Yolov3.cfg and download it and edit it as Yolo custom v3 file and upload it again to the same location. Only need to uncomment training area and yolo layers as per custom model.

# %%
# %cd /content/drive/My Drive/yolo_custom_model_Training
# Out:
# /content/drive/My Drive/yolo_custom_model_Training

# %%
# !python custom_data/creating-files-data-and-name.py

# %%
# !python custom_data/creating-train-and-test-txt-files.py

# %%
# !darknet/darknet detector train custom_data/labelled_data.data darknet/cfg/yolov3_custom.cfg custom_weight/darknet53.conv.74 -dont_show
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
# yolov3_custom
#  0 : compute_capability = 610, cudnn_half = 0, GPU: Tesla P4
# net.optimized_memory = 0
# mini_batch = 1, batch = 64, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
# ...
